# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv") #read csv file and save it to the data frame df

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
i = 0
for country in df["Country"]:
    if country == "Kazakhstan":
        i += 1
print(i)
# Out:
# 64

# %%
df.info() #This is a method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
m = 0
f = 0
for gender in df["Gender"]:
    if gender == "Man":
        m += 1
    elif gender == "Woman":
        f += 1
print(m, f)
# Out:
# 77919 6344

# %% [markdown]
# Setting up the view to view all raws

# %%
schema_df = pd.read_csv("data/survey_results_schema.csv")

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option("display.max_rows", 85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd.set_option("display.max_columns", 85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %% [markdown]
# # Dataframes and series data types

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
people = {
    "First" : ["Daniyar", "John", "Jane"],
    "Second" : ["Syrlybyev", 'Doe', 'Doe'],
    "Email" : ['daniyar.syrlybayev@company.com', 'john.doe@company.com', 'jane.doe@company.com']
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#      First     Second                           Email
# 0  Daniyar  Syrlybyev  daniyar.syrlybayev@company.com
# 1     John        Doe            john.doe@company.com
# 2     Jane        Doe            jane.doe@company.com

# %% [markdown]
# Access single columns as in dictionary

# %%
people_df["Second"]
# Out:
# 0    Syrlybyev
# 1          Doe
# 2          Doe
# Name: Second, dtype: object

# %%
people_df["Email"]
#OR
people_df.Email
# Out:
# 0    daniyar.syrlybayev@company.com
# 1              john.doe@company.com
# 2              jane.doe@company.com
# Name: Email, dtype: object

# %%
type(people_df["Email"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Seris is list of data but with much more functionality
#
# DataFrame is the container for multiple series

# %%
people_df.Email
# Out:
# 0    daniyar.syrlybayev@company.com
# 1              john.doe@company.com
# 2              jane.doe@company.com
# Name: Email, dtype: object

# %%
people_df[["Second", "Email"]] #pass list of labels
# Out:
#       Second                           Email
# 0  Syrlybyev  daniyar.syrlybayev@company.com
# 1        Doe            john.doe@company.com
# 2        Doe            jane.doe@company.com

# %%
type(people_df[["Second", "Email"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This is dataframe type

# %%
people_df.columns
# Out:
# Index(['First', 'Second', 'Email'], dtype='object')

# %% [markdown]
# To access raws
# loc
# iloc

# %%
people_df.iloc[0]
# Out:
# First                            Daniyar
# Second                         Syrlybyev
# Email     daniyar.syrlybayev@company.com
# Name: 0, dtype: object

# %%
type(people_df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
 people_df.iloc[[0, 1]] #pass list of indices
# Out:
#      First     Second                           Email
# 0  Daniyar  Syrlybyev  daniyar.syrlybayev@company.com
# 1     John        Doe            john.doe@company.com

# %%
people_df.iloc[[0, 1], [1, 2]] #rows first argument, columns second arguments
# Out:
#       Second                           Email
# 0  Syrlybyev  daniyar.syrlybayev@company.com
# 1        Doe            john.doe@company.com

# %%
people_df.iloc[[0, 1], [2]]
# Out:
#                             Email
# 0  daniyar.syrlybayev@company.com
# 1            john.doe@company.com

# %% [markdown]
# iloc - search by integer
#
# loc - search by labels

# %%
people_df.loc[[0, 1], ["Email", "Second"]]
# Out:
#                             Email     Second
# 0  daniyar.syrlybayev@company.com  Syrlybyev
# 1            john.doe@company.com        Doe

# %%
for i in range(df.shape[0]):
    people = df.loc[i]
    if people["Country"] == "Kazakhstan" and people["Gender"] == "Woman":
        print(people)
        print("------------------------------------------------------------------")
# Out:
# Respondent                                                            15078
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                      Once a month or more often
# OpenSource                OSS is, on average, of HIGHER quality than pro...
# Employment                Independent contractor, freelancer, or self-em...
# Country                                                          Kazakhstan
# Student                                                                  No
# EdLevel                            Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor                                Web development or web design
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                                 NaN
# ...

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df["Sexuality"].value_counts()
# Out:
# Straight / Heterosexual                            70155
# Bisexual                                            3440
# Gay or Lesbian                                      1798
# Bisexual;Straight / Heterosexual                     494
# Bisexual;Gay or Lesbian                              114
# Bisexual;Gay or Lesbian;Straight / Heterosexual      108
# Gay or Lesbian;Straight / Heterosexual                38
# Name: Sexuality, dtype: int64

# %%
type(df["Sexuality"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df["Sexuality"].value_counts()[1]
# Out:
# 3440

# %%
for i in range(df.shape[0]):
    people = df.loc[i]
    if people["Country"] == "Kazakhstan" and people["Gender"] == "Woman":
        print(people["Sexuality"])
        print("------------------------------------------------------------------")
# Out:
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------
# Straight / Heterosexual
# ------------------------------------------------------------------

# %%
df.loc[0:2, "Hobbyist" : "Employment"] #Note that [ ] in loc and iloc and : passes last raw/column inclusively
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# # Indecies

# %% [markdown]
# How to set unique non-defult indices on the rows

# %%
people_df["Email"]
# Out:
# 0    daniyar.syrlybayev@company.com
# 1              john.doe@company.com
# 2              jane.doe@company.com
# Name: Email, dtype: object

# %%
people_df.set_index(["Email"])
# Out:
#                                   First     Second
# Email
# daniyar.syrlybayev@company.com  Daniyar  Syrlybyev
# john.doe@company.com               John        Doe
# jane.doe@company.com               Jane        Doe

# %%
people_df #but it still have default index
# Out:
#      First     Second                           Email
# 0  Daniyar  Syrlybyev  daniyar.syrlybayev@company.com
# 1     John        Doe            john.doe@company.com
# 2     Jane        Doe            jane.doe@company.com

# %%
people_df.set_index(["Email"], inplace = True)

# %%
people_df
# Out:
#                                   First     Second
# Email
# daniyar.syrlybayev@company.com  Daniyar  Syrlybyev
# john.doe@company.com               John        Doe
# jane.doe@company.com               Jane        Doe

# %%
people_df.index
# Out:
# Index(['daniyar.syrlybayev@company.com', 'john.doe@company.com',
#        'jane.doe@company.com'],
#       dtype='object', name='Email')

# %%
people_df.reset_index(inplace = True)

# %%
people_df
# Out:
#                             Email    First     Second
# 0  daniyar.syrlybayev@company.com  Daniyar  Syrlybyev
# 1            john.doe@company.com     John        Doe
# 2            jane.doe@company.com     Jane        Doe

# %%
df.columns[1]
# Out:
# 'Respondent'

# %%
df.set_index(df.columns[1], inplace = True)

# %%
df.loc[1]
# Out:
# index                                                                     0
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent") #read csv file, set unique index and save it to the data frame df

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df.reset_index(inplace = True)
schema_df.set_index("Column", inplace = True)
schema_df.sort_index(inplace = True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending = False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# # Filtering

# %%
people_df
# Out:
#                             Email    First     Second
# 0  daniyar.syrlybayev@company.com  Daniyar  Syrlybyev
# 1            john.doe@company.com     John        Doe
# 2            jane.doe@company.com     Jane        Doe

# %%
print(*filter(lambda x: x["Second"] == "Doe", people_df.set_index("Second")))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DANIYA~1\AppData\Local\Temp/ipykernel_17852/1818015503.py in <module>
# ----> 1 print(*filter(lambda x: x["Second"] == "Doe", people_df.set_index("Second")))
#
# C:\Users\DANIYA~1\AppData\Local\Temp/ipykernel_17852/1818015503.py in <lambda>(x)
# ----> 1 print(*filter(lambda x: x["Second"] == "Doe", people_df.set_index("Second")))
#
# TypeError: string indices must be integers

# %%
filt = people_df["Second"] == "Doe"

# %%
people_df[filt]
# Out:
#                   Email First Second
# 1  john.doe@company.com  John    Doe
# 2  jane.doe@company.com  Jane    Doe

# %%
people_df[people_df["Second"] == "Doe"]
# Out:
#                   Email First Second
# 1  john.doe@company.com  John    Doe
# 2  jane.doe@company.com  Jane    Doe

# %%
people_df.loc[filt]
# Out:
#                   Email First Second
# 1  john.doe@company.com  John    Doe
# 2  jane.doe@company.com  Jane    Doe

# %%
people_df.loc[filt, "Email"]
# Out:
# 1    john.doe@company.com
# 2    jane.doe@company.com
# Name: Email, dtype: object

# %% [markdown]
# and/or symbols for filtering = &/|

# %%
filt = (people_df["Second"] == "Doe") & (people_df["First"] == "John")

# %%
people_df[filt].loc[:, "Email"]
# Out:
# 1    john.doe@company.com
# Name: Email, dtype: object

# %%
people_df.loc[filt, "Email"]
# Out:
# 1    john.doe@company.com
# Name: Email, dtype: object

# %%
filt = (people_df["Second"] == "Syrlybyev") | (people_df["First"] == "John")

# %%
people_df[filt].loc[:, "Email"]
# Out:
# 0    daniyar.syrlybayev@company.com
# 1              john.doe@company.com
# Name: Email, dtype: object

# %% [markdown]
# # To get the opposite of the results above add tilde

# %%
people_df[~filt].loc[:, "Email"]
# Out:
# 2    jane.doe@company.com
# Name: Email, dtype: object

# %%
filt = ~((people_df["Second"] == "Syrlybyev") | (people_df["First"] == "John"))

# %%
people_df[filt].loc[:, "Email"]
# Out:
# 2    jane.doe@company.com
# Name: Email, dtype: object

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
filt1 = df['CompFreq'] == "Monthly"
filt2 = df['CompFreq'] == "Yearly"
filt3 = df['CompFreq'] == "Weekly"

# %%
dfM = df[filt1].loc[:, "CompTotal"] * 12
dfY = df[filt2].loc[:, "CompTotal"]
dfW = df[filt3].loc[:, "CompTotal"] * 52

# %%
schema_df.loc["ConvertedComp"]
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: ConvertedComp, dtype: object

# %%
filt = (df["ConvertedComp"] > 70000) & (df["MainBranch"] == df.loc[6, "MainBranch"]) & (df["UndergradMajor"] == df.loc[45, "UndergradMajor"]) & (df["Gender"] == "Woman")
df[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6746        I am not primarily a developer, but I write co...      Yes
# 7301        I am not primarily a developer, but I write co...      Yes
# 10458       I am not primarily a developer, but I write co...       No
# 15517       I am not primarily a developer, but I write co...      Yes
# 21030       I am not primarily a developer, but I write co...      Yes
# 22081       I am not primarily a developer, but I write co...       No
# 27923       I am not primarily a developer, but I write co...      Yes
# 52406       I am not primarily a developer, but I write co...      Yes
# 56527       I am not primarily a developer, but I write co...       No
# 56943       I am not primarily a developer, but I write co...       No
# 70219       I am not primarily a developer, but I write co...      Yes
# 75649       I am not primarily a developer, but I write co...      Yes
# ...

# %%
A = list(filter(lambda y: y.count("Python") == 1, list(map(lambda x: str(x).split(";"), df["LanguageWorkedWith"]))))
B = list(filter(lambda y: y.count("C++") == 1, list(map(lambda x: str(x).split(";"), df["LanguageWorkedWith"]))))
C = list(filter(lambda y: y.count("Java") == 1, list(map(lambda x: str(x).split(";"), df["LanguageWorkedWith"]))))
D = list(filter(lambda y: y.count("HTML/CSS") == 1, list(map(lambda x: str(x).split(";"), df["LanguageWorkedWith"]))))

# %%
print(len(A), len(B), len(C), len(D))
# Out:
# 36443 20524 35917 55466

# %%
countries = ["United States", "India", "United Kingdom", "Germany", "Canada"]

# %%
high_sal = (df["ConvertedComp"] > 70000)
country = (df["Country"].isin(countries) == True)

# %%
df[high_sal & country]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88873                          I am a developer by profession      Yes
# 88874                          I am a developer by profession      Yes
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt3 = df["LanguageWorkedWith"].str.contains("Python", na = False)

# %%
df[filt3].loc[:, "LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# # Updating Values

# %%
people_df
# Out:
#                             Email    First     Second
# 0  daniyar.syrlybayev@company.com  Daniyar  Syrlybyev
# 1            john.doe@company.com     John        Doe
# 2            jane.doe@company.com     Jane        Doe

# %%
people_df.columns
# Out:
# Index(['Email', 'First', 'Second'], dtype='object')

# %%
people_df.columns = ["email", "last name", "first name"]

# %%
people_df
# Out:
#                             email last name first name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1            john.doe@company.com      John        Doe
# 2            jane.doe@company.com      Jane        Doe

# %%
people_df.columns = list(map(lambda x: x.upper(), people_df.columns))

# %%
people_df
# Out:
#                             EMAIL LAST NAME FIRST NAME
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1            john.doe@company.com      John        Doe
# 2            jane.doe@company.com      Jane        Doe

# %%
#OR we can use
people_df.columns = [x.lower() for x in people_df.columns]
people_df
# Out:
#                             email last name first name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1            john.doe@company.com      John        Doe
# 2            jane.doe@company.com      Jane        Doe

# %%
people_df.columns = people_df.columns.str.replace(" ", "_")

# %%
people_df
# Out:
# 0         dan
# 1        John
# 2    janyffer
# Name: First, dtype: object

# %%
people_df.rename({"first_name": "First",
                 "last_name":"Last"}, inplace = True) #to rename only specific columns

# %%
people_df
# Out:
#                             email last_name first_name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1            john.doe@company.com      John        Doe
# 2            jane.doe@company.com      Jane        Doe

# %%
people_df.loc[[1]] = ["john.smith@company.com", "John", "Smith"] # To change one entire row

# %%
people_df
# Out:
#                             email last_name first_name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1          john.smith@company.com      John      Smith
# 2            jane.doe@company.com      Jane        Doe

# %%
people_df.loc[[2], ["first_name"]] = "Smith" #To change only specific column in a given row

# %%
people_df
# Out:
#                             email last_name first_name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1          john.smith@company.com      John      Smith
# 2            jane.doe@company.com      Jane      Smith

# %% [markdown]
# # apply - applies some functions to dataframes or series. Does not change the function only prints its modified version
#
# # map
#
# # applymap
#
# # replace

# %%
people_df["email"].apply(len)
# Out:
# 0    30
# 1    22
# 2    20
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
people_df["email"].apply(update_email)
# Out:
# 0    DANIYAR.SYRLYBAYEV@COMPANY.COM
# 1            JOHN.SMITH@COMPANY.COM
# 2              JANE.DOE@COMPANY.COM
# Name: email, dtype: object

# %%
people_df
# Out:
#                             email last_name first_name
# 0  daniyar.syrlybayev@company.com   Daniyar  Syrlybyev
# 1          john.smith@company.com      John      Smith
# 2            jane.doe@company.com      Jane      Smith

# %%
people_df["Email"] = people_df["Email"].apply(update_email)

# %%
people_df["Email"] = people_df["Email"].apply(lambda x: x.lower())

# %%
people_df
# Out:
#      First     Second                           Email
# 0  Daniyar  Syrlybyev  daniyar.syrlybayev@company.com
# 1     John        Doe            john.doe@company.com
# 2     Jane        Doe            jane.doe@company.com

# %% [markdown]
# ##  Apply on DataFrame

# %%
people_df.apply(len, axis = "rows")
# Out:
# First     3
# Second    3
# Email     3
# dtype: int64

# %% [markdown]
# applies len to each series on DataFrame

# %%
people_df.apply(len, axis = "columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
people_df.apply(pd.Series.min)
# Out:
# First                            Daniyar
# Second                               Doe
# Email     daniyar.syrlybayev@company.com
# dtype: object

# %% [markdown]
# Note that function now works with Series, not with the values in the series

# %% [markdown]
# applymap - works with dataframes and applies function to every value in dataframe

# %%
people_df.applymap(len)
# Out:
#    First  Second  Email
# 0      7       9     30
# 1      4       3     20
# 2      4       3     20

# %%
people_df.applymap(lambda x: x.lower())
# Out:
#      First     Second                           Email
# 0  daniyar  syrlybyev  daniyar.syrlybayev@company.com
# 1     john        doe            john.doe@company.com
# 2     jane        doe            jane.doe@company.com

# %% [markdown]
# map method works only with the series to substite one value with another

# %%
people_df["First"].map({"Daniyar" : "dan", "Jane": "janyffer"})
# Out:
# 0         dan
# 1         NaN
# 2    janyffer
# Name: First, dtype: object

# %%
people_df["First"]
# Out:
# 0    Daniyar
# 1       John
# 2       Jane
# Name: First, dtype: object

# %%
people_df["First"].replace({"Daniyar" : "dan", "Jane": "janyffer"})
# Out:
# 0         dan
# 1        John
# 2    janyffer
# Name: First, dtype: object

# %%
people_df = people_df["First"].replace({"Daniyar" : "dan", "Jane": "janyffer"})

# %%
people_df
# Out:
# 0         dan
# 1        John
# 2    janyffer
# Name: First, dtype: object

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df = pd.read_csv("data/survey_results_public.csv") #read csv file and save it to the data frame df

# %%
df.set_index("Respondent", inplace = True)

# %%
df.rename(columns = {"EdLevel" : "Degree"}, inplace = True)

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df["Hobbyist"] = df["Hobbyist"].apply(lambda x: bool((x == "Yes") * True + (x == "No") * False))

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %%
df['Hobbyist'] = df["Hobbyist"].map({True: "Yes", False: "No"})

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...
